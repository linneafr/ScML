# %%
import pandas as pd
import csv
# data with daily aqi averages for Grensásv was downloaded from aqicn.org
#eliminate whitespaces from the csv?


df_air_quality = pd.read_csv('grensasv_iceland-air-quality.csv', error_bad_lines=False)
print(df_air_quality.shape)
df_air_quality.head(7)
# Out:
# (2154, 6)
#        date  pm25  pm10  no2 so2 co
# 0  2022/1/3    26     7   22   3
# 1  2022/1/4    25     5    3   3
# 2  2022/1/5    59    62    3   3
# 3  2022/1/6   123     8    5   3
# 4  2022/1/7    18     9    4   3
# 5  2022/1/8    44     6    5   3
# 6  2022/1/9    42   101    6   2

# %%
import csv
import pandas as pd


        
df_air_quality = pd.read_csv('grensasv_iceland-air-quality.csv', error_bad_lines=False)
df_air_quality['date'].str.strip()
df_air_quality['pm25'].str.strip()
df_air_quality['pm10'].str.strip()
df_air_quality['no2'].str.strip()
df_air_quality['co'].str.strip()
    
df_air_quality.head()
# Out:
#        date  pm25 pm10  no2 so2 co
# 0  2022/1/3    26    7   22   3
# 1  2022/1/4    25    5    3   3
# 2  2022/1/5    59   62    3   3
# 3  2022/1/6   123    8    5   3
# 4  2022/1/7    18    9    4   3

# %%
print(df_air_quality.columns)
df_air_quality.date = df_air_quality.date.apply(pd.to_datetime)
print(df_air_quality.info())
df_air_quality.head()
# Out:
# Index(['date', 'pm25', 'pm10', 'no2', 'so2', 'co'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2154 entries, 0 to 2153
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2154 non-null   datetime64[ns]
#  1   pm25    2154 non-null   object
#  2   pm10    2154 non-null   object
#  3   no2     2154 non-null   object
#  4   so2     2154 non-null   object
#  5   co      2154 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 101.1+ KB
# None
#         date  pm25 pm10  no2 so2 co
# 0 2022-01-03    26    7   22   3
# 1 2022-01-04    25    5    3   3
# 2 2022-01-05    59   62    3   3
# 3 2022-01-06   123    8    5   3
# 4 2022-01-07    18    9    4   3

# %%
# add column AQI
df_air_quality['AQI'] = df_air_quality[['pm25','pm10','no2', 'so2', 'co']].apply(max, axis=1)
df_air_quality.head()
# Out:
#         date  pm25 pm10  no2 so2 co  AQI
# 0 2022-01-03    26    7   22   3       7
# 1 2022-01-04    25    5    3   3       5
# 2 2022-01-05    59   62    3   3      62
# 3 2022-01-06   123    8    5   3       8
# 4 2022-01-07    18    9    4   3       9

# %%
#save to new csv file:
df_air_quality.to_csv('air_qality_data.csv', index=False)

# %%
# load weather data

df_weather = pd.read_csv('reykjavik_2020-07-01_to_2023-01-01.csv')
print(df_weather.shape)
df_weather.head(7)
# Out:
# (915, 26)
#      address    datetime  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  reykjavik  2020-07-01     12.0      8.2  10.3          12.0           5.9
# 1  reykjavik  2020-07-02     15.5      8.1  11.9          15.5           8.1
# 2  reykjavik  2020-07-03     14.5      9.3  12.0          14.5           8.7
# 3  reykjavik  2020-07-04     12.6      8.9  10.5          12.6           7.2
# 4  reykjavik  2020-07-05     16.3      8.2  12.6          16.3           7.6
# 5  reykjavik  2020-07-06     16.0      7.4  12.5          16.0           6.3
# 6  reykjavik  2020-07-07     12.8      7.9  10.7          12.8           6.5
#
#    feelslike  dew  humidity  ...  windgust  windspeed  winddir  \
# 0        9.4  7.9      86.0  ...       NaN       15.6    259.2
# 1       11.9  6.8      71.9  ...       NaN       21.6    226.7
# 2       11.9  4.5      60.8  ...       NaN       22.6    125.6
# 3       10.1  4.9      68.5  ...       NaN       19.9    291.1
# 4       12.5  6.9      69.3  ...       NaN       26.5    318.7
# 5       12.5  4.4      58.8  ...       NaN       19.7    314.3
# 6       10.5  6.6      75.8  ...       NaN       16.1    258.2
#
#   sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0           1014.3        90.3         9.8           272.6         23.3
# 1           1006.3        46.9        12.9           339.3         29.1
# 2           1002.7        66.2        22.1           331.4         28.6
# 3            999.9        82.5        19.3           234.0         20.5
# 4           1006.0        39.2        16.9           317.0         27.6
# 5           1013.4        25.6        23.7           311.3         26.9
# 6           1014.6        48.4        17.7           266.5         23.0
#
#    uvindex  severerisk
# 0        7         NaN
# 1        8         NaN
# 2        8         NaN
# 3        6         NaN
# 4        8         NaN
# 5        7         NaN
# 6        7         NaN
#
# [7 rows x 26 columns]

# %%
df_weather.windgust.isna().sum()
# Out:
# 331

# %%
df_weather.windgust
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 910    14.8
# 911    13.0
# 912    14.0
# 913    33.1
# 914    44.3
# Name: windgust, Length: 915, dtype: float64

# %%
df_weather.severerisk.isna().sum()
# Out:
# 558

# %%
df_weather.severerisk.unique()
# Out:
# array([nan, 10.])

# %%
df_weather.columns
# Out:
# Index(['address', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk'],
#       dtype='object')

# %%
df_weather.preciptype.unique()
# Out:
# array(['rain', nan, 'rain,snow', 'snow', 'rain,freezingrain,snow'],
#       dtype=object)

# %%
# replacing rain=1, rain,snow=2, snow=3, rain,freezingrain,snow=4

df_weather['preciptype'].replace('rain', 1, inplace=True)
df_weather['preciptype'].replace('rain,snow', 2, inplace=True)
df_weather['preciptype'].replace('snow', 3, inplace=True)
df_weather['preciptype'].replace('rain,freezingrain,snow', 4, inplace=True)
df_weather.preciptype
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 910    3.0
# 911    NaN
# 912    NaN
# 913    3.0
# 914    3.0
# Name: preciptype, Length: 915, dtype: float64

# %%
#save to new csv file:
df_weather.to_csv('weather_data.csv', index=False)

# %%
from datetime import datetime

def timestamp_2_time(x):
    dt_obj = datetime.strptime(str(x), '%Y-%m-%d')
    dt_obj = dt_obj.timestamp() * 1000
    return int(dt_obj)

df_air_quality.date
# Out:
# 0      2022-01-03
# 1      2022-01-04
# 2      2022-01-05
# 3      2022-01-06
# 4      2022-01-07
#           ...
# 2149   2018-12-14
# 2150   2018-12-15
# 2151   2018-12-16
# 2152   2016-08-27
# 2153   2016-08-28
# Name: date, Length: 2154, dtype: datetime64[ns]

# %%
df_air_quality.date = df_air_quality.date.apply(timestamp_2_time)
df_air_quality.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-cebb9bd9e2ca> in <module>
# ----> 1 df_air_quality.date = df_air_quality.date.apply(timestamp_2_time)
#       2 df_air_quality.head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198         Anguilla     11300
#    4199         Iceland     337000
# -> 4200         dtype: int64
#    4201
#    4202         The `n` smallest elements where ``n=3``. Default `keep` value is
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-138-4c09e9cb7272> in timestamp_2_time(x)
#       2
#       3 def timestamp_2_time(x):
# ----> 4     dt_obj = datetime.strptime(str(x), '%Y-%m-%d')
#       5     dt_obj = dt_obj.timestamp() * 1000
#       6     return int(dt_obj)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains:  00:00:00

# %%
df_weather.datetime = df_weather.datetime.apply(timestamp_2_time)
df_weather.head()
# Out:
#      address       datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  reykjavik  1593554400000     12.0      8.2  10.3          12.0
# 1  reykjavik  1593640800000     15.5      8.1  11.9          15.5
# 2  reykjavik  1593727200000     14.5      9.3  12.0          14.5
# 3  reykjavik  1593813600000     12.6      8.9  10.5          12.6
# 4  reykjavik  1593900000000     16.3      8.2  12.6          16.3
#
#    feelslikemin  feelslike  dew  humidity  ...  windgust  windspeed  winddir  \
# 0           5.9        9.4  7.9      86.0  ...       NaN       15.6    259.2
# 1           8.1       11.9  6.8      71.9  ...       NaN       21.6    226.7
# 2           8.7       11.9  4.5      60.8  ...       NaN       22.6    125.6
# 3           7.2       10.1  4.9      68.5  ...       NaN       19.9    291.1
# 4           7.6       12.5  6.9      69.3  ...       NaN       26.5    318.7
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0            1014.3        90.3         9.8           272.6         23.3
# 1            1006.3        46.9        12.9           339.3         29.1
# 2            1002.7        66.2        22.1           331.4         28.6
# 3             999.9        82.5        19.3           234.0         20.5
# 4            1006.0        39.2        16.9           317.0         27.6
#
#    uvindex  severerisk
# 0        7         NaN
# 1        8         NaN
# 2        8         NaN
# 3        6         NaN
# 4        8         NaN
#
# [5 rows x 26 columns]
